# %% [markdown]
# <a href="https://colab.research.google.com/github/NastyaShanova/My_First_Test_Repo/blob/main/%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Пример исползования MarkDawn
# Нужно сделать:
# 1. Список
# 2. Рисунок
# 3. Таблицу
# 4. Ссылку
#
# ![image.png](data:image/png;base64,...)
#
# First column name  | Second column name
# -------------------|------------------
# Row 1, Col 1       | Row 1, Col 2
# Row 2, Col 1       | Row 2, Col 2
#
# https://colab.research.google.com/notebooks/intro.ipynb#scrollTo=5fCEDCU_qrC0
